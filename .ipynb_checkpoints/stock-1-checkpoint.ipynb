# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import  LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import LSTM, Dense

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %% [markdown]
# # 데이터 불러오기

# %%
# 데이터 불러오기
df = pd.read_csv('../data/stock/train.csv')

# %% [markdown]
# # 데이터 확인 - EDA

# %%
df.head()
# Out:
#          일자     종목코드     종목명     거래량     시가     고가     저가     종가
# 0  20210601  A060310      3S  166690   2890   2970   2885   2920
# 1  20210601  A095570  AJ네트웍스   63836   5860   5940   5750   5780
# 2  20210601  A006840   AK홀딩스  103691  35500  35600  34150  34400
# 3  20210601  A054620     APS  462544  14600  14950  13800  14950
# 4  20210601  A265520   AP시스템  131987  29150  29150  28800  29050

# %%
df.tail()
# Out:
#               일자     종목코드     종목명      거래량    시가    고가    저가    종가
# 987995  20230530  A189980  흥국에프엔비   272284  3005  3035  2955  2980
# 987996  20230530  A000540    흥국화재    50218  3250  3255  3195  3215
# 987997  20230530  A003280    흥아해운   130664  1344  1395  1340  1370
# 987998  20230530  A037440      희림   141932  9170  9260  9170  9200
# 987999  20230530  A238490      힘스  2611843  6410  8220  6300  8220

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988000 entries, 0 to 987999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   일자      988000 non-null  int64
#  1   종목코드    988000 non-null  object
#  2   종목명     988000 non-null  object
#  3   거래량     988000 non-null  int64
#  4   시가      988000 non-null  int64
#  5   고가      988000 non-null  int64
#  6   저가      988000 non-null  int64
#  7   종가      988000 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 60.3+ MB

# %%
df.describe()
# Out:
#                  일자           거래량            시가            고가            저가  \
# count  9.880000e+05  9.880000e+05  9.880000e+05  9.880000e+05  9.880000e+05
# mean   2.021974e+07  7.734265e+05  2.587701e+04  2.634938e+04  2.542335e+04
# std    6.822396e+03  4.839914e+06  6.590845e+04  6.689822e+04  6.490307e+04
# min    2.021060e+07  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.021113e+07  3.653900e+04  3.775000e+03  3.865000e+03  3.700000e+03
# 50%    2.022053e+07  1.140220e+05  8.630000e+03  8.810000e+03  8.470000e+03
# 75%    2.022113e+07  3.672998e+05  2.130000e+04  2.180000e+04  2.085000e+04
# max    2.023053e+07  7.822434e+08  1.770000e+06  1.784000e+06  1.756000e+06
#
#                  종가
# count  9.880000e+05
# mean   2.600283e+04
# std    6.587082e+04
# min    8.500000e+01
# 25%    3.890000e+03
# 50%    8.700000e+03
# 75%    2.140000e+04
# max    1.770000e+06

# %%
print(len(df['종목명'].unique()))
# Out:
# 2000

# %%
print(len(df['종목코드'].unique()))
# Out:
# 2000

# %%
# 일자 : 20210601 ~ 20230530
# 총 2000개 종목명(종목코드)


# 피처 : 일자, 종목코드, 종목명, 거래량, 시가, 고가, 저가, 종가
# null값 없음
# 종목코드, 종목명 : object 형 & 의미 겹침 -> 하나로 합쳐도 괜찮음
# 종목코드 -> 인코딩하기
# 일자, 종목코드, 거래량, 시가, 고가, 저가, 종가의 기준값이 다르기 때문에 꼭 정규화 시킨 뒤 학습시키기


# 종가를 바탕으로 종목코드별 순위 알아보기

# 주식에 영향을 주는 요인 : 금리, 전쟁, 인플레이션, 경제성장

# 금리(금리가 오르면 내려감)
# 전쟁(국제정세 어지러우면 내려감)
# 인플레이션(오르면 내려감)
# 경제성장(오르면 함께 오름)

# %% [markdown]
# # 전처리

# %%
# 금리 feature에 추가 (한국은행 기준)
df['금리']=0

#금리 삽입
# 20210601 ~ 20210825 : 0.5
df['금리'] = np.where((df['일자'] >= 20210601) & (df['일자'] <= 20210825), 0.5, df['금리'])

# 20210826 ~ 20211124 : 0.75
df['금리'] = np.where((df['일자'] >= 20210826) & (df['일자'] <= 20211124), 0.75, df['금리'])

# 20211125 ~ 20220113 : 1.0
df['금리'] = np.where((df['일자'] >= 20211125) & (df['일자'] <= 20220113), 1.0, df['금리'])

# 20220114 ~ 20220413 : 1.25
df['금리'] = np.where((df['일자'] >= 20220114) & (df['일자'] <= 20220413), 1.25, df['금리'])

# 20220414 ~ 20220525 : 1.5
df['금리'] = np.where((df['일자'] >= 20220414) & (df['일자'] <= 20220525), 1.5, df['금리'])

# 20220526 ~ 20220712 : 1.75
df['금리'] = np.where((df['일자'] >= 20220526) & (df['일자'] <= 20220712), 1.75, df['금리'])

# 20220713 ~ 20220824 : 2.25
df['금리'] = np.where((df['일자'] >= 20220713) & (df['일자'] <= 20220824), 2.25, df['금리'])

# 20220825 ~ 20221011 : 2.5
df['금리'] = np.where((df['일자'] >= 20220825) & (df['일자'] <= 20221011), 2.5, df['금리'])

# 20221012 ~ 20221123 : 3.0
df['금리'] = np.where((df['일자'] >= 20221012) & (df['일자'] <= 20221123), 3.0, df['금리'])

# 20221124 ~ 20230112 : 3.25
df['금리'] = np.where((df['일자'] >= 20221124) & (df['일자'] <= 20230112), 3.25, df['금리'])

# 20230113 ~ 지금 : 3.5
df['금리'] = np.where((df['일자'] >= 20230113) , 3.5, df['금리'])

# %%
df.head()
# Out:
#          일자     종목코드     종목명     거래량     시가     고가     저가     종가   금리
# 0  20210601  A060310      3S  166690   2890   2970   2885   2920  0.5
# 1  20210601  A095570  AJ네트웍스   63836   5860   5940   5750   5780  0.5
# 2  20210601  A006840   AK홀딩스  103691  35500  35600  34150  34400  0.5
# 3  20210601  A054620     APS  462544  14600  14950  13800  14950  0.5
# 4  20210601  A265520   AP시스템  131987  29150  29150  28800  29050  0.5

# %%
# 인플레이션(오르면 내려감), 소비자물가지수(CPI) (KOSTAT - Korea 기준)
df['CPI']=0

# CPI 삽입
# 20210601 : 2.30 %
df['CPI'] = np.where((df['일자'] == 20210601) , 2.30, df['CPI'])

# 20210602 ~ 20210701 : 2.60 % 
df['CPI'] = np.where((df['일자'] >= 20210602) & (df['일자'] <= 20210701), 2.60, df['CPI'])

# 20210702 ~ 20210802 : 2.40 % 
df['CPI'] = np.where((df['일자'] >= 20210702) & (df['일자'] <= 20210802), 2.40, df['CPI'])

# 20210803 ~ 20211005 : 2.60 %
df['CPI'] = np.where((df['일자'] >= 20210803) & (df['일자'] <= 20211005), 2.60, df['CPI'])

# 20211006 ~ 20211101 : 2.50 %
df['CPI'] = np.where((df['일자'] >= 20211006) & (df['일자'] <= 20211101), 2.50, df['CPI'])

# 20211102 ~ 20211201 : 3.20 %
df['CPI'] = np.where((df['일자'] >= 20211102) & (df['일자'] <= 20211201), 3.20, df['CPI'])

# 20211202 ~ 20220203 : 3.70 %
df['CPI'] = np.where((df['일자'] >= 20211202) & (df['일자'] <= 20220203), 3.70, df['CPI'])

# 20220204 ~ 20220303 : 3.60 %
df['CPI'] = np.where((df['일자'] >= 20220204) & (df['일자'] <= 20220303), 3.60, df['CPI'])

# 20220304 ~ 20220404 : 3.70 %
df['CPI'] = np.where((df['일자'] >= 20220304) & (df['일자'] <= 20220404), 3.70, df['CPI'])

# 20220405 ~ 20220502 : 4.10 %
df['CPI'] = np.where((df['일자'] >= 20220405) & (df['일자'] <= 20220502), 4.10, df['CPI'])

# 20220503 ~ 20220602 : 4.80 %
df['CPI'] = np.where((df['일자'] >= 20220503) & (df['일자'] <= 20220602), 4.80, df['CPI'])

# 20220603 ~ 20220704 : 5.40 %
df['CPI'] = np.where((df['일자'] >= 20220603) & (df['일자'] <= 20220704), 5.40, df['CPI'])

# 20220705 ~ 20220801 : 6.00 %
df['CPI'] = np.where((df['일자'] >= 20220705) & (df['일자'] <= 20220801), 6.00, df['CPI'])

# 20220802 ~ 20220901 : 6.30 %
df['CPI'] = np.where((df['일자'] >= 20220802) & (df['일자'] <= 20220901), 6.30, df['CPI'])

# 20220902 ~ 20221004 : 5.70 %
df['CPI'] = np.where((df['일자'] >= 20220902) & (df['일자'] <= 20221004), 5.70, df['CPI'])

# 20221005 ~ 20221101 : 5.60 %
df['CPI'] = np.where((df['일자'] >= 20221005) & (df['일자'] <= 20221101), 5.60, df['CPI'])

# 20221102 ~ 20221201 : 5.70 %
df['CPI'] = np.where((df['일자'] >= 20221102) & (df['일자'] <= 20221201), 5.70, df['CPI'])

# 20221202 ~ 20230201 5.00 %
df['CPI'] = np.where((df['일자'] >= 20221202) & (df['일자'] <= 20230201), 5.00, df['CPI'])

# 20230202 ~ 20230305 5.20 %
df['CPI'] = np.where((df['일자'] >= 20230202) & (df['일자'] <= 20230305), 5.20, df['CPI'])

# 20230306 ~ 20230403 4.80 %
df['CPI'] = np.where((df['일자'] >= 20230306) & (df['일자'] <= 20230403), 4.80, df['CPI'])

# 20230404 ~ 20230501 : 4.20 %
df['CPI'] = np.where((df['일자'] >= 20230404) & (df['일자'] <= 20230501), 4.20, df['CPI'])

# 20230502 ~ 20230601 : 3.30 %
df['CPI'] = np.where((df['일자'] >= 20230502) & (df['일자'] <= 20230601), 3.30, df['CPI'])

# %%
df.head()
# Out:
#          일자     종목코드     종목명     거래량     시가     고가     저가     종가   금리  CPI
# 0  20210601  A060310      3S  166690   2890   2970   2885   2920  0.5  2.3
# 1  20210601  A095570  AJ네트웍스   63836   5860   5940   5750   5780  0.5  2.3
# 2  20210601  A006840   AK홀딩스  103691  35500  35600  34150  34400  0.5  2.3
# 3  20210601  A054620     APS  462544  14600  14950  13800  14950  0.5  2.3
# 4  20210601  A265520   AP시스템  131987  29150  29150  28800  29050  0.5  2.3

# %%
# 경제성장률 (아시아경제은행 기준)
# 경제성장률 = [(금년도 실질GDP - 전년도 실질GDP) ÷ 전년도 실질GDP] × 100

df['REG']=0

# 2021 : 4.3 %
df['REG'] = np.where((df['일자'] >= 20210601) & (df['일자'] <= 20211231), 4.3, df['REG'])

# 2022 : 2.6 %
df['REG'] = np.where((df['일자'] >= 20220101) & (df['일자'] <= 20221231), 2.6, df['REG'])

# 2023 : 1.3 %
df['REG'] = np.where((df['일자'] >= 20230101) & (df['일자'] <= 20230530), 1.3, df['REG'])

# %%
df.head()
# Out:
#          일자     종목코드     종목명     거래량     시가     고가     저가     종가   금리  CPI  \
# 0  20210601  A060310      3S  166690   2890   2970   2885   2920  0.5  2.3
# 1  20210601  A095570  AJ네트웍스   63836   5860   5940   5750   5780  0.5  2.3
# 2  20210601  A006840   AK홀딩스  103691  35500  35600  34150  34400  0.5  2.3
# 3  20210601  A054620     APS  462544  14600  14950  13800  14950  0.5  2.3
# 4  20210601  A265520   AP시스템  131987  29150  29150  28800  29050  0.5  2.3
#
#    REG
# 0  4.3
# 1  4.3
# 2  4.3
# 3  4.3
# 4  4.3

# %%
plt.hist(df['종가'], bins=10, facecolor='blue', alpha=0.5)
plt.show()

# %%
st=df.copy()

# %%
plt.boxplot(st['종가'])
plt.show()

# %%
st.describe()
# Out:
#                  일자           거래량            시가            고가            저가  \
# count  9.880000e+05  9.880000e+05  9.880000e+05  9.880000e+05  9.880000e+05
# mean   2.021974e+07  7.734265e+05  2.587701e+04  2.634938e+04  2.542335e+04
# std    6.822396e+03  4.839914e+06  6.590845e+04  6.689822e+04  6.490307e+04
# min    2.021060e+07  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.021113e+07  3.653900e+04  3.775000e+03  3.865000e+03  3.700000e+03
# 50%    2.022053e+07  1.140220e+05  8.630000e+03  8.810000e+03  8.470000e+03
# 75%    2.022113e+07  3.672998e+05  2.130000e+04  2.180000e+04  2.085000e+04
# max    2.023053e+07  7.822434e+08  1.770000e+06  1.784000e+06  1.756000e+06
#
#                  종가             금리            CPI            REG
# count  9.880000e+05  988000.000000  988000.000000  988000.000000
# mean   2.600283e+04       1.933198       4.238664       2.840081
# std    6.587082e+04       1.109671       1.218774       1.071386
# min    8.500000e+01       0.500000       2.300000       1.300000
# 25%    3.890000e+03       1.000000       3.200000       2.600000
# 50%    8.700000e+03       1.750000       4.150000       2.600000
# 75%    2.140000e+04       3.250000       5.400000       4.300000
# max    1.770000e+06       3.500000       6.300000       4.300000

# %%
# 가장 낮게 거래된 종가 항목 확인 
st.loc[df['종가']==8.500000e+01	]
# 판타지오 : 85원
# Out:
#               일자     종목코드   종목명       거래량  시가  고가  저가  종가   금리  CPI  REG
# 305717  20220110  A032800  판타지오  21750231  89  89  83  85  1.0  3.7  2.6

# %%
# 가장 높게 거래된 종가 항목 확인
st.loc[df['종가']==1.770000e+06]
# lg생활건강 : 1,770,000원
# Out:
#              일자     종목코드     종목명    거래량       시가       고가       저가       종가  \
# 44131  20210701  A051900  LG생활건강  35712  1770000  1784000  1750000  1770000
#
#         금리  CPI  REG
# 44131  0.5  2.6  4.3

# %% [markdown]
# ### 저가와 종가의 차이가 많이남... 나중에 정확도가 많이 떨어질 경우 한 번 더 확인 후 일반화를 위한 전처리 진행

# %%
# 일자별 주식 추세 확인
close_price_by_date = df.groupby("일자").종가.mean()

# 시각화
plt.plot(close_price_by_date)

# %%
# 떨어졌다 유지되엇다 다시 급락했다 조금 오르고 있음

# %%
# 종목명별 중간값을 가지고 비싼 애들부터 인코딩해주기
st_price = st.groupby('종목명')['종가'].agg('mean').sort_values(ascending=False)
print('변환전\n', st_price[:5])
# Out:
# 변환전
#  종목명
# LG생활건강      927289.473684
# 태광산업        919595.141700
# 삼성바이오로직스    837560.728745
# LG화학        671966.599190
# 삼성SDI       656896.761134
# Name: 종가, dtype: float64

# %%
#가격별로 0~ 인코딩 해주기
for i, a in enumerate(list(st_price.index)):
    st.loc[df['종목명'] == a, '종목명'] = i 
st_price = st.groupby('종목명')['종가'].agg('mean').sort_values(ascending=False)
print('변환후\n', st_price[:5])
# Out:
# 변환후
#  종목명
# 0    927289.473684
# 1    919595.141700
# 2    837560.728745
# 3    671966.599190
# 4    656896.761134
# Name: 종가, dtype: float64

# %%
st.head()
# Out:
#          일자     종목코드   종목명     거래량     시가     고가     저가     종가   금리  CPI  REG
# 0  20210601  A060310  1681  166690   2890   2970   2885   2920  0.5  2.3  4.3
# 1  20210601  A095570  1290   63836   5860   5940   5750   5780  0.5  2.3  4.3
# 2  20210601  A006840   529  103691  35500  35600  34150  34400  0.5  2.3  4.3
# 3  20210601  A054620   741  462544  14600  14950  13800  14950  0.5  2.3  4.3
# 4  20210601  A265520   498  131987  29150  29150  28800  29050  0.5  2.3  4.3

# %%
stock=st.copy()

# %%
# 분석 보기 편하기 위해 컬럼명 변경
stock.columns = ['date', 'code', 'name', 'volume', 'start', 'high', 'low','finish','interest','cpi','reg']

# %%
stock.head()
# Out:
#        date     code  name  volume  start   high    low  finish  interest  \
# 0  20210601  A060310  1681  166690   2890   2970   2885    2920       0.5
# 1  20210601  A095570  1290   63836   5860   5940   5750    5780       0.5
# 2  20210601  A006840   529  103691  35500  35600  34150   34400       0.5
# 3  20210601  A054620   741  462544  14600  14950  13800   14950       0.5
# 4  20210601  A265520   498  131987  29150  29150  28800   29050       0.5
#
#    cpi  reg
# 0  2.3  4.3
# 1  2.3  4.3
# 2  2.3  4.3
# 3  2.3  4.3
# 4  2.3  4.3

# %%
# code+ name -> name만 남기기
stock = stock.drop(['code'], axis=1)
stock.head()
# Out:
#        date  name  volume  start   high    low  finish  interest  cpi  reg
# 0  20210601  1681  166690   2890   2970   2885    2920       0.5  2.3  4.3
# 1  20210601  1290   63836   5860   5940   5750    5780       0.5  2.3  4.3
# 2  20210601   529  103691  35500  35600  34150   34400       0.5  2.3  4.3
# 3  20210601   741  462544  14600  14950  13800   14950       0.5  2.3  4.3
# 4  20210601   498  131987  29150  29150  28800   29050       0.5  2.3  4.3

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988000 entries, 0 to 987999
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      988000 non-null  int64
#  1   name      988000 non-null  object
#  2   volume    988000 non-null  int64
#  3   start     988000 non-null  int64
#  4   high      988000 non-null  int64
#  5   low       988000 non-null  int64
#  6   finish    988000 non-null  int64
#  7   interest  988000 non-null  float64
#  8   cpi       988000 non-null  float64
#  9   reg       988000 non-null  float64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 75.4+ MB

# %%
# name 자료형 변환 (카테고리형으로)
stock['name'] = stock['name'].astype('category').cat.codes

# %%
stock.head()
# Out:
#        date  name  volume  start   high    low  finish  interest  cpi  reg
# 0  20210601  1681  166690   2890   2970   2885    2920       0.5  2.3  4.3
# 1  20210601  1290   63836   5860   5940   5750    5780       0.5  2.3  4.3
# 2  20210601   529  103691  35500  35600  34150   34400       0.5  2.3  4.3
# 3  20210601   741  462544  14600  14950  13800   14950       0.5  2.3  4.3
# 4  20210601   498  131987  29150  29150  28800   29050       0.5  2.3  4.3

# %%
stock.tail()
# Out:
#             date  name   volume  start  high   low  finish  interest  cpi  reg
# 987995  20230530  1620   272284   3005  3035  2955    2980       3.5  3.3  1.3
# 987996  20230530  1562    50218   3250  3255  3195    3215       3.5  3.3  1.3
# 987997  20230530  1816   130664   1344  1395  1340    1370       3.5  3.3  1.3
# 987998  20230530  1041   141932   9170  9260  9170    9200       3.5  3.3  1.3
# 987999  20230530  1078  2611843   6410  8220  6300    8220       3.5  3.3  1.3

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988000 entries, 0 to 987999
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      988000 non-null  int64
#  1   name      988000 non-null  int16
#  2   volume    988000 non-null  int64
#  3   start     988000 non-null  int64
#  4   high      988000 non-null  int64
#  5   low       988000 non-null  int64
#  6   finish    988000 non-null  int64
#  7   interest  988000 non-null  float64
#  8   cpi       988000 non-null  float64
#  9   reg       988000 non-null  float64
# dtypes: float64(3), int16(1), int64(6)
# memory usage: 69.7 MB

# %%
# 추후 종가를 예측해야 하기 때문에 종가를 맨 뒤로...
#데이터 재배열
stock = stock[['date', 'name', 'volume','start','high','low','interest', 'cpi', 'reg','finish']]
stock.head()
# Out:
#        date  name  volume  start   high    low  interest  cpi  reg  finish
# 0  20210601  1681  166690   2890   2970   2885       0.5  2.3  4.3    2920
# 1  20210601  1290   63836   5860   5940   5750       0.5  2.3  4.3    5780
# 2  20210601   529  103691  35500  35600  34150       0.5  2.3  4.3   34400
# 3  20210601   741  462544  14600  14950  13800       0.5  2.3  4.3   14950
# 4  20210601   498  131987  29150  29150  28800       0.5  2.3  4.3   29050

# %% [markdown]
# # 상관관계 분석

# %%
# 상관분석 진행

#상관관계 행렬
st_corr=stock.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(st_corr, annot=True, cmap="viridis")
plt.show()

# %%
# 서로 다른 기준점이기 때문에 각 변수간의 다중공선성x

# 종가와 관련있는 변수 (high,start,low는 본인가)
corr_order = st_corr.corr()['finish'].abs().sort_values(ascending=False)
corr_order
# Out:
# finish      1.000000
# high        0.999999
# start       0.999999
# low         0.999999
# name        0.882111
# cpi         0.323484
# volume      0.318582
# interest    0.287232
# reg         0.253129
# date        0.252595
# Name: finish, dtype: float64

# %%
# 종가는 종목명에 가장 영향을 많이 받음
# 순서대로 소비자물가지수와 금리, 경제성장률에도 영향을 받는 것으로 나타남

# 시간이 지날수록 경제성장률이 좋지 않다는 것을 알 수 있음
# 시간이 지날수록 금리가 점점 올라가고 있음을 알 수 있음
# 금리가 오를수록 경제성장률이 좋지 않음
# 금리가 오를수록 소비자물가지수가 오름(인플레 높아짐)

# %%
'''
# pca 확인
# PCA를 수행
pca = PCA()
pca.fit(stock)

# PCA 결과 해석
print(pca.explained_variance_ratio_)
'''
# Out:
# '\n# pca 확인\n# PCA를 수행\npca = PCA()\npca.fit(stock)\n\n# PCA 결과 해석\nprint(pca.explained_variance_ratio_)\n'

# %%
#그룹별로 묶기 (2000개 레코드로 묶는 작업)
stock_group = stock.groupby('name')

# %%
stock_summary = stock_group.agg({'volume': 'sum', 'start': 'mean', 'high': 'max', 'low': 'min', 'interest': 'mean', 'cpi': 'mean', 'reg': 'mean', 'finish': 'mean'})

# %%
stock_summary.head()
# Out:
#          volume          start     high     low  interest       cpi       reg  \
# name
# 0      30263285  929366.396761  1784000  499500  1.933198  4.238664  2.840081
# 1        373865  920558.704453  1318000  655000  1.933198  4.238664  2.840081
# 2      33248847  838020.242915  1047000  693000  1.933198  4.238664  2.840081
# 3     133692256  673210.526316   910000  437000  1.933198  4.238664  2.840081
# 4     132858894  657114.372470   828000  462500  1.933198  4.238664  2.840081
#
#              finish
# name
# 0     927289.473684
# 1     919595.141700
# 2     837560.728745
# 3     671966.599190
# 4     656896.761134

# %%
# 정규화하기
# MinMaxScaler 클래스 생성
scaler = MinMaxScaler()

# MinMaxScaler 클래스의 fit_transform() 메서드 사용 데이터 정규화
normalized_data = scaler.fit_transform(stock_summary)

# 정규화된 데이터, 데이터 프레임으로 다시 변환
ndf = pd.DataFrame(normalized_data, columns=stock_summary.columns)

# %%
ndf.head()
# Out:
#      volume     start      high       low  interest  cpi  reg    finish
# 0  0.002352  1.000000  1.000000  0.720779       0.0  0.0  0.0  1.000000
# 1  0.000029  0.990523  0.738789  0.945166       0.0  0.0  0.0  0.991700
# 2  0.002584  0.901711  0.586883  1.000000       0.0  0.0  0.0  0.903209
# 3  0.010389  0.724376  0.510090  0.630592       0.0  0.0  0.0  0.724582
# 4  0.010324  0.707056  0.464126  0.667388       0.0  0.0  0.0  0.708326

# %%
stock_ndf = pd.DataFrame(ndf).to_csv('../data/stock/ndf.csv', index=False)

# %% [markdown]
# # 모델링

# %%
# 데이터 나누기
X = ndf.iloc[:, :-1]
y = ndf.iloc[:,[-1]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.head()
# Out:
#         volume     start      high       low  interest  cpi  reg
# 491   0.002691  0.024126  0.019983  0.016176       0.0  0.0  0.0
# 1015  0.003850  0.009515  0.007595  0.008009       0.0  0.0  0.0
# 1599  0.004608  0.003668  0.003004  0.003319       0.0  0.0  0.0
# 1555  0.010296  0.003984  0.003408  0.003651       0.0  0.0  0.0
# 957   0.011963  0.010230  0.006951  0.008817       0.0  0.0  0.0

# %%
y_train.head()
# Out:
#         finish
# 491   0.023921
# 1015  0.009258
# 1599  0.003405
# 1555  0.003717
# 957   0.009965

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1600, 7)
# (1600, 1)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 7)
# (400, 1)

# %%
X_train_csv = pd.DataFrame(X_train).to_csv('../data/stock/X_train.csv', index=False)
y_train_csv = pd.DataFrame(y_train).to_csv('../data/stock/y_train.csv', index=False)
X_test_csv = pd.DataFrame(X_test).to_csv('../data/stock/X_test.csv', index=False)
y_test_csv = pd.DataFrame(y_test).to_csv('../data/stock/y_test.csv', index=False)

# %%
from tensorflow.keras.layers import Dropout

from tensorflow.keras.initializers import GlorotUniform
from tensorflow.keras.regularizers import l2

'''
model = Sequential([
  LSTM(32, activation='relu', return_sequences=True,  input_shape=(ndf.shape[1] - 1, 1)),
  Dropout(0.4),
  LSTM(units=32, activation='relu'),
  Dropout(0.4),
  Dense(1, kernel_initializer=tf.keras.initializers.GlorotUniform(), kernel_regularizer=tf.keras.regularizers.l2(0.1))
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer=optimizer, loss='mse')
'''
'''
model = Sequential([
  LSTM(64, activation='relu', return_sequences=True,  input_shape=(ndf.shape[1] - 1, 1)),
  Dropout(0.2),
  LSTM(units=32, activation='relu'),
  Dropout(0.2),
  Dense(1, kernel_regularizer=tf.keras.regularizers.l2(0.1))
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='mse')
'''
'''
model = Sequential([
  LSTM(64, activation='relu', return_sequences=True,  input_shape=(ndf.shape[1] - 1, 1)),
  Dropout(0.4),
  LSTM(units=64, activation='relu'),
  Dropout(0.4),
  Dense(1, kernel_regularizer=tf.keras.regularizers.l2(0.1))
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.002)

model.compile(optimizer=optimizer, loss='mse')

'''

tf.random.set_seed(1)

model = Sequential()

model.add(LSTM(128, activation='relu', return_sequences=True,  input_shape=(ndf.shape[1] - 1, 1)))
model.add(LSTM(units=128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(Dense(1))
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 128)            66560
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 198,273
# Trainable params: 198,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습하기
history = model.fit(X_train, y_train, epochs=12, batch_size=80, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/12
# 16/16 [==============================] - 3s 41ms/step - loss: 0.0048 - val_loss: 0.0018
# Epoch 2/12
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 3/12
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 4/12
# 16/16 [==============================] - 0s 12ms/step - loss: 9.1463e-04 - val_loss: 8.8680e-04
# Epoch 5/12
# 16/16 [==============================] - 0s 12ms/step - loss: 9.5325e-04 - val_loss: 8.6788e-04
# Epoch 6/12
# 16/16 [==============================] - 0s 12ms/step - loss: 6.6366e-04 - val_loss: 5.6192e-04
# Epoch 7/12
# 16/16 [==============================] - 0s 12ms/step - loss: 6.0121e-04 - val_loss: 3.9857e-04
# Epoch 8/12
# 16/16 [==============================] - 0s 12ms/step - loss: 6.3065e-04 - val_loss: 5.5297e-04
# Epoch 9/12
# 16/16 [==============================] - 0s 12ms/step - loss: 4.2859e-04 - val_loss: 2.4047e-04
# Epoch 10/12
# 16/16 [==============================] - 0s 12ms/step - loss: 3.7074e-04 - val_loss: 3.4042e-04
# Epoch 11/12
# 16/16 [==============================] - 0s 12ms/step - loss: 3.4507e-04 - val_loss: 1.4961e-04
# Epoch 12/12
# 16/16 [==============================] - 0s 12ms/step - loss: 3.4114e-04 - val_loss: 1.4357e-04

# %%
# 예측하기
pred = model.predict(X_test)
print(y_test.shape, pred.shape)
# Out:
# 13/13 [==============================] - 0s 3ms/step
# (400, 1) (400, 1)

# %%
# 실제값과 예측값 확인하기
predictions = np.array(pred)
actual_values = np.array(y_test)

# %%
# RMSE를 계산(낮을 수록 정확함)
rmse = mean_squared_error(y_test, predictions)
print('rmse :',rmse)

# R^2을 계산(R^2가 1에 가까울수록 모델이 데이터를 잘 설명)
r2 = r2_score(y_test, predictions)
print('r2 :',r2)

# MAE를 계산(MAE가 낮을수록 예측값과 실제값이 가까워짐)
mae = mean_absolute_error(y_test, predictions)
print('mae :',mae)
# Out:
# rmse : 0.0002077054009293669
# r2 : 0.9615982602789044
# mae : 0.005557019707256456

# %%
# 예측값과 실제값
X_test['predict'] = pred
X_test['real'] = y_test['finish']

# %%
X_test.head()
# Out:
#         volume     start      high       low  interest  cpi  reg   predict  \
# 1075  0.025081  0.008788  0.011855  0.006494       0.0  0.0  0.0  0.011023
# 1277  0.022800  0.006531  0.005858  0.005743       0.0  0.0  0.0  0.008549
# 1248  0.001769  0.006850  0.004271  0.007908       0.0  0.0  0.0  0.007563
# 1452  0.078408  0.004764  0.004198  0.003795       0.0  0.0  0.0  0.010550
# 1612  0.046644  0.003218  0.004378  0.000000       0.0  0.0  0.0  0.007613
#
#           real
# 1075  0.008553
# 1277  0.006293
# 1248  0.006602
# 1452  0.004500
# 1612  0.003351

# %%
modelResult = pd.DataFrame(X_test).to_csv('../data/stock/result.csv', index=False)

# %% [markdown]
# # 교차검증 -- val_lose로 확인

# %%
'''
# K-Fold CV 수행
kfold = KFold(n_splits=5)
cv_scores = []

# 훈련 세트와 검증 세트 성능 저장C
train_loss = []
val_loss = []

for train_index, test_index in kfold.split(X_train):
    X_train_cv, X_test_cv = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_cv, y_test_cv = y_train.iloc[train_index], y_train.iloc[test_index]

    # 모델 학습
    model.fit(X_train_cv, y_train_cv, epochs=10, batch_size=100, verbose=1)

    # 모델성능 평가
    y_pred = model.predict(X_test_cv)
    
    mse = np.mean(np.square(y_pred - y_test_cv))
    mae = np.mean(np.abs(y_pred - y_test_cv))
    r2 = r2_score(y_test_cv, y_pred)
    rmse = np.sqrt(mse)
    cv_scores.append([mae, r2, rmse])
'''
# Out:
# '\n# K-Fold CV 수행\nkfold = KFold(n_splits=5)\ncv_scores = []\n\n# 훈련 세트와 검증 세트 성능 저장C\ntrain_loss = []\nval_loss = []\n\nfor train_index, test_index in kfold.split(X_train):\n    X_train_cv, X_test_cv = X_train.iloc[train_index], X_train.iloc[test_index]\n    y_train_cv, y_test_cv = y_train.iloc[train_index], y_train.iloc[test_index]\n\n    # 모델 학습\n    model.fit(X_train_cv, y_train_cv, epochs=10, batch_size=100, verbose=1)\n\n    # 모델성능 평가\n    y_pred = model.predict(X_test_cv)\n    \n    mse = np.mean(np.square(y_pred - y_test_cv))\n    mae = np.mean(np.abs(y_pred - y_test_cv))\n    r2 = r2_score(y_test_cv, y_pred)\n    rmse = np.sqrt(mse)\n    cv_scores.append([mae, r2, rmse])\n'

# %%
'''
# K-Fold CV 결과 출력
cv_scores = list(cv_scores)
print(cv_scores)
'''
# Out:
# '\n# K-Fold CV 결과 출력\ncv_scores = list(cv_scores)\nprint(cv_scores)\n'

# %%
'''
print('Fold', 'MAE', 'R2', 'RMSE')
for fold, (mae, r2, rmse) in enumerate(cv_scores):
    print(f'{fold + 1}', mae, r2, rmse)
'''
# Out:
# "\nprint('Fold', 'MAE', 'R2', 'RMSE')\nfor fold, (mae, r2, rmse) in enumerate(cv_scores):\n    print(f'{fold + 1}', mae, r2, rmse)\n"

# %%
'''
fold_result = pd.DataFrame(cv_scores, columns=[ 'mae', 'r2', 'rmse'])
print(fold_result)
'''
# Out:
# "\nfold_result = pd.DataFrame(cv_scores, columns=[ 'mae', 'r2', 'rmse'])\nprint(fold_result)\n"

# %%
# 모델 예측하기 (전체)
# 예측값 가장 큰것부터 1부터 해서 인코딩

# %%
# 데이터 나누기
x_data = ndf.iloc[:, :-1]
y_data = ndf.iloc[:,[-1]]

# %%
x_data.head()
# Out:
#      volume     start      high       low  interest  cpi  reg
# 0  0.002352  1.000000  1.000000  0.720779       0.0  0.0  0.0
# 1  0.000029  0.990523  0.738789  0.945166       0.0  0.0  0.0
# 2  0.002584  0.901711  0.586883  1.000000       0.0  0.0  0.0
# 3  0.010389  0.724376  0.510090  0.630592       0.0  0.0  0.0
# 4  0.010324  0.707056  0.464126  0.667388       0.0  0.0  0.0

# %%
x_data.describe()
# Out:
#             volume        start         high          low  interest     cpi  \
# count  2000.000000  2000.000000  2000.000000  2000.000000    2000.0  2000.0
# mean      0.029690     0.027844     0.024883     0.022790       0.0     0.0
# std       0.061578     0.068053     0.057612     0.062157       0.0     0.0
# min       0.000000     0.000000     0.000000     0.000000       0.0     0.0
# 25%       0.003883     0.004274     0.004117     0.003115       0.0     0.0
# 50%       0.010900     0.009581     0.008758     0.007323       0.0     0.0
# 75%       0.031574     0.023759     0.021700     0.018038       0.0     0.0
# max       1.000000     1.000000     1.000000     1.000000       0.0     0.0
#
#           reg
# count  2000.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
y_data.head()
# Out:
#      finish
# 0  1.000000
# 1  0.991700
# 2  0.903209
# 3  0.724582
# 4  0.708326

# %%
predict_close = model.predict(x_data)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
x_data['predict_close'] = predict_close
x_data['real_close'] = y_data['finish']

# %%
x_data.head()
# Out:
#      volume     start      high       low  interest  cpi  reg  predict_close  \
# 0  0.002352  1.000000  1.000000  0.720779       0.0  0.0  0.0       0.814865
# 1  0.000029  0.990523  0.738789  0.945166       0.0  0.0  0.0       0.829449
# 2  0.002584  0.901711  0.586883  1.000000       0.0  0.0  0.0       0.772369
# 3  0.010389  0.724376  0.510090  0.630592       0.0  0.0  0.0       0.563694
# 4  0.010324  0.707056  0.464126  0.667388       0.0  0.0  0.0       0.559446
#
#    real_close
# 0    1.000000
# 1    0.991700
# 2    0.903209
# 3    0.724582
# 4    0.708326

# %%
'''
#수익률 계산하기
#수익률 = (예측 가격 - 실제 가격) / 실제 가격

x_data['return'] = (x_data['predict_close'] - x_data['real_close']) / x_data['real_close']
'''
# Out:
# "\n#수익률 계산하기\n#수익률 = (예측 가격 - 실제 가격) / 실제 가격\n\nx_data['return'] = (x_data['predict_close'] - x_data['real_close']) / x_data['real_close']\n"

# %%
#x_data.head()

# %%
x_data['name'] = st['종목명']

# %%
x_data.head()
# Out:
#      volume     start      high       low  interest  cpi  reg  predict_close  \
# 0  0.002352  1.000000  1.000000  0.720779       0.0  0.0  0.0       0.814865
# 1  0.000029  0.990523  0.738789  0.945166       0.0  0.0  0.0       0.829449
# 2  0.002584  0.901711  0.586883  1.000000       0.0  0.0  0.0       0.772369
# 3  0.010389  0.724376  0.510090  0.630592       0.0  0.0  0.0       0.563694
# 4  0.010324  0.707056  0.464126  0.667388       0.0  0.0  0.0       0.559446
#
#    real_close  name
# 0    1.000000  1681
# 1    0.991700  1290
# 2    0.903209   529
# 3    0.724582   741
# 4    0.708326   498

# %%
#x_data['code'] = st['종목코드']

# %%
#x_data.head()

# %%
#result_data = x_data[['code','return']]

# %%
#result_data.head()

# %%
re = x_data[['predict_close', 'real_close']]

# %%
re.head()
# Out:
#    predict_close  real_close
# 0       0.814865    1.000000
# 1       0.829449    0.991700
# 2       0.772369    0.903209
# 3       0.563694    0.724582
# 4       0.559446    0.708326

# %%
# x_renorm = x_norm * (max_value - min_value) + min_value

# %%
max_value = 1.770000e+06
min_value= 8.500000e+01
    
re['predict_close'] = re['predict_close'] * (max_value - min_value) + min_value
re['real_close'] = re['real_close'] * (max_value - min_value) + min_value
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_100\2374949235.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   re['predict_close'] = re['predict_close'] * (max_value - min_value) + min_value
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_100\2374949235.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   re['real_close'] = re['real_close'] * (max_value - min_value) + min_value

# %%
re.head()
# Out:
#    predict_close    real_close
# 0   1.442327e+06  1.770000e+06
# 1   1.468139e+06  1.755310e+06
# 2   1.367112e+06  1.598689e+06
# 3   9.977762e+05  1.282534e+06
# 4   9.902571e+05  1.253762e+06

# %%
re['return'] = (re['predict_close'] - re['real_close']) / re['real_close']
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_100\808787774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   re['return'] = (re['predict_close'] - re['real_close']) / re['real_close']

# %%
re.head()
# Out:
#    predict_close    real_close    return
# 0   1.442327e+06  1.770000e+06 -0.185126
# 1   1.468139e+06  1.755310e+06 -0.163601
# 2   1.367112e+06  1.598689e+06 -0.144854
# 3   9.977762e+05  1.282534e+06 -0.222027
# 4   9.902571e+05  1.253762e+06 -0.210172

# %%
re['code'] = st['종목코드']
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_100\1182562461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   re['code'] = st['종목코드']

# %%
re.head()
# Out:
#    predict_close    real_close    return     code
# 0   1.442327e+06  1.770000e+06 -0.185126  A060310
# 1   1.468139e+06  1.755310e+06 -0.163601  A095570
# 2   1.367112e+06  1.598689e+06 -0.144854  A006840
# 3   9.977762e+05  1.282534e+06 -0.222027  A054620
# 4   9.902571e+05  1.253762e+06 -0.210172  A265520

# %%
re.describe()
# Out:
#        predict_close    real_close       return
# count   2.000000e+03  2.000000e+03  2000.000000
# mean    4.818895e+04  4.925091e+04     2.058134
# std     9.775566e+04  1.207162e+05    19.959134
# min     7.598278e+03  8.500000e+01    -0.731794
# 25%     1.421557e+04  7.406869e+03    -0.070022
# 50%     2.022780e+04  1.678076e+04     0.097210
# 75%     4.101589e+04  4.173617e+04     0.805500
# max     1.468139e+06  1.770000e+06   509.374911

# %%
res_data = re[['code','return']]

# %%
res_data.head()
# Out:
#       code    return
# 0  A060310 -0.185126
# 1  A095570 -0.163601
# 2  A006840 -0.144854
# 3  A054620 -0.222027
# 4  A265520 -0.210172

# %%
res_data.describe()
# Out:
#             return
# count  2000.000000
# mean      2.058134
# std      19.959134
# min      -0.731794
# 25%      -0.070022
# 50%       0.097210
# 75%       0.805500
# max     509.374911

# %%
# 마이너스값 양수로 만들어주기, 수익률은 -1보다 크기 때문에 그냥 1을 더해 양수로 만드어준다.
# (수익률 문제라 같은 값으로 더해주면 크게 상관없음)
res_data['re_return'] = res_data['return'].map(lambda x: x+1)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_100\3587695542.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_data['re_return'] = res_data['return'].map(lambda x: x+1)

# %%
#오류값 있는지 확인(inf / NaN)
if np.isinf(res_data['re_return']).any():
    print('inf값이 있음.')

if np.isnan(res_data['re_return']).any():
    print('NaN값이 있음.')

#없음

# %%
res_data.head()
# Out:
#       code    return  re_return
# 0  A060310 -0.185126   0.814874
# 1  A095570 -0.163601   0.836399
# 2  A006840 -0.144854   0.855146
# 3  A054620 -0.222027   0.777973
# 4  A265520 -0.210172   0.789828

# %%
res_data.describe()
# Out:
#             return    re_return
# count  2000.000000  2000.000000
# mean      2.058134     3.058134
# std      19.959134    19.959134
# min      -0.731794     0.268206
# 25%      -0.070022     0.929978
# 50%       0.097210     1.097210
# 75%       0.805500     1.805500
# max     509.374911   510.374911

# %%
# 같은 값 있는지 확인

# %%
if res_data["re_return"].duplicated().any():
    print("`re_return` 열에 같은 값이 있음.")
else:
    print("`re_return` 열에 같은 값이 없음.")
# Out:
# `re_return` 열에 같은 값이 없습니다.

# %%
# return값 큰값부터 1~ 순위 부여
res_data = res_data.sort_values("re_return", ascending=False)
res_data["re_return_rank"] = res_data["re_return"].rank(ascending=False)

# %%
res_data.head()
# Out:
#          code      return   re_return  re_return_rank
# 1998  A037440  509.374911  510.374911             1.0
# 1997  A003280  481.913128  482.913128             2.0
# 1999  A238490  469.227619  470.227619             3.0
# 1987  A215090  219.198659  220.198659             4.0
# 1972  A298020  104.844058  105.844058             5.0

# %%
res_data["re_return_rank"] = res_data["re_return_rank"].astype(int)

# %%
res_data.head()
# Out:
#          code      return   re_return  re_return_rank
# 1998  A037440  509.374911  510.374911               1
# 1997  A003280  481.913128  482.913128               2
# 1999  A238490  469.227619  470.227619               3
# 1987  A215090  219.198659  220.198659               4
# 1972  A298020  104.844058  105.844058               5

# %%
#필요한 피처만 남기기
final = res_data[['code','re_return_rank']]

# %%
final.head()
# Out:
#          code  re_return_rank
# 1998  A037440               1
# 1997  A003280               2
# 1999  A238490               3
# 1987  A215090               4
# 1972  A298020               5

# %%
#1~2000까지 잘 들어갔는지 확인
final.describe()
# Out:
#        re_return_rank
# count     2000.000000
# mean      1000.500000
# std        577.494589
# min          1.000000
# 25%        500.750000
# 50%       1000.500000
# 75%       1500.250000
# max       2000.000000

# %%
#제출 준비

# %%
final.rename(columns={'code': '종목코드', 're_return_rank': '순위'}, inplace=True)
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_100\110320421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final.rename(columns={'code': '종목코드', 're_return_rank': '순위'}, inplace=True)

# %%
final.head()
# Out:
#          종목코드  순위
# 1998  A037440   1
# 1997  A003280   2
# 1999  A238490   3
# 1987  A215090   4
# 1972  A298020   5

# %%
submit = pd.read_csv('../data/stock/sample_submission.csv')

# %%
submit.head()
# Out:
#       종목코드  순위
# 0  A000020   1
# 1  A000040   2
# 2  A000050   3
# 3  A000070   4
# 4  A000080   5

# %%
final_submit = submit[['종목코드']].merge(final[['종목코드', '순위']], on='종목코드', how='left')
final_submit
# Out:
#          종목코드    순위
# 0     A000020  1680
# 1     A000040  1979
# 2     A000050  1456
# 3     A000070  1215
# 4     A000080    30
# ...       ...   ...
# 1995  A375500  1947
# 1996  A378850    80
# 1997  A383220  1993
# 1998  A383310   882
# 1999  A383800  1717
#
# [2000 rows x 2 columns]

# %%
final_submit.to_csv('../data/stock/final_submit.csv', index=False)

# %%
# 점수 : -0.23445
